# %% [markdown]
# ## Мой проект предсказывает количество аренд велосипедов

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")
bike_data = pd.read_csv("hour.csv",delimiter=",")

# %%
bike_data
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

data = pd.read_csv('hour.csv')
X = data.drop('cnt', axis=1)
y = data['cnt']
X_encoded = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

model1 = LinearRegression()
model1.fit(X_train, y_train)

y_pred1 = model1.predict(X_test)
mse = mean_squared_error(y_test, y_pred1)
mae = mean_absolute_error(y_test, y_pred1)
r2 = r2_score(y_test, y_pred1)

print(f'Mean Squared Error of LinearRegression: {mse}')
print(f'Mean Absolute Error LinearRegression: {mae}')
print(f'R^2 Score LinearRegression: {r2}')
# Out:
# Mean Squared Error of LinearRegression: 8.1921902434034735e-22
# Mean Absolute Error LinearRegression: 2.472663708487422e-11
# R^2 Score LinearRegression: 1.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

data = pd.read_csv('hour.csv')
X = data.drop('cnt', axis=1)
y = data['cnt']
X_encoded = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

model2 = RandomForestRegressor(n_estimators=100, random_state=42)
model2.fit(X_train, y_train)

y_pred2 = model.predict(X_test)

mse2 = mean_squared_error(y_test, y_pred2)
mae2 = mean_absolute_error(y_test, y_pred2)
r22 = r2_score(y_test, y_pred2)

print(f'Mean Squared Error of RandomForestRegressor: {mse2}')
print(f'Mean Absolute Error of RandomForestRegressor: {mae2}')
print(f'R^2 Score of RandomForestRegressor: {r22}')
# Out:
# Mean Squared Error of RandomForestRegressor: 7.674923158803224
# Mean Absolute Error of RandomForestRegressor: 0.9773446490218642
# R^2 Score of RandomForestRegressor: 0.9997576243972562
